# %% [markdown]
# # Lab 4 - Session 2
# ## Clone the Group Fork and Run the Trained Model on Raspberry Pi 5 with a USB Webcam
#
# **Duration:** 2 hours
# **Session 2 marks:** 40 points
# **Official deliverable:** `SecXX_GroupXX_Lab4_Session2.pdf`
#
# The Raspberry Pi 5 development kit already has a screen, operating system, Git, Python, OpenCV, and Ultralytics. Students do not prepare an SD card and do not use SSH.
#
# Use this notebook as the walkthrough and evidence record. Run commands directly in Terminal on the Pi screen, capture screenshots or photographs, upload them into the corresponding evidence blocks, answer all 20 questions, and print the completed notebook to PDF.

# %%
#@title Student, group, and fork information
GROUP_MEMBER_NAMES = "" #@param {type:"string"}
SECTION_NUMBER = 1 #@param {type:"integer"}
GROUP_NUMBER = 1 #@param {type:"integer"}
FORK_OWNER = "" #@param {type:"string"}
FORK_REPOSITORY_NAME = "lab4-megalopa" #@param {type:"string"}
SESSION1_COMMIT_ID = "" #@param {type:"string"}
PI_KIT_NUMBER = "" #@param {type:"string"}

assert GROUP_MEMBER_NAMES.strip()
assert SECTION_NUMBER in (1, 2)
assert 1 <= GROUP_NUMBER <= 25
assert FORK_OWNER.strip()
assert FORK_REPOSITORY_NAME.strip()
assert SESSION1_COMMIT_ID.strip()

FORK_URL = f"https://github.com/{FORK_OWNER}/{FORK_REPOSITORY_NAME}.git"
print("Group members:", GROUP_MEMBER_NAMES)
print("Group fork:", FORK_URL)
print("Session 1 commit:", SESSION1_COMMIT_ID)
print("Pi kit:", PI_KIT_NUMBER)

# %% [markdown]
# ## Evidence upload helper
#
# Run the next cell once. Each later evidence cell lets you upload one or more screenshots or photographs and displays them directly in the notebook.

# %%
from pathlib import Path
from google.colab import files
from IPython.display import Image as DisplayImage, display

EVIDENCE_DIR = Path("/content/session2_evidence")
EVIDENCE_DIR.mkdir(exist_ok=True)

def upload_evidence(label):
    print("Upload evidence for:", label)
    uploaded = files.upload()
    saved = []
    for name, data in uploaded.items():
        path = EVIDENCE_DIR / f"{label}_{Path(name).name}"
        path.write_bytes(data)
        saved.append(path)
        try:
            display(DisplayImage(filename=str(path)))
        except Exception:
            print("Saved:", path)
    return saved

# %% [markdown]
# ## 1. Verify the prepared Raspberry Pi 5 kit
#
# Run on the Pi terminal:
#
# ```bash
# hostname
# cat /proc/device-tree/model; echo
# uname -m
# python3 --version
# vcgencmd measure_temp
# ```

# %%
upload_evidence('01_pi_system')

# %% [markdown]
# | Item | Result |
# |---|---|
# | Raspberry Pi model | TYPE HERE |
# | Architecture | TYPE HERE |
# | Python version | TYPE HERE |
# | Initial CPU temperature | TYPE HERE |
#
# **Q1.** What output confirms that the device is the expected Raspberry Pi 5 environment? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q2.** Why should Python version and initial CPU temperature be recorded before inference? **[2 marks]**
# **Answer:** TYPE HERE

# %% [markdown]
# ## 2. Verify the USB webcam
#
# Connect the USB webcam and run:
#
# ```bash
# ls -l /dev/video*
# python3 shared/pi5/check_pi5_environment.py --camera-index 0
# ```
#
# If index `0` fails, try another listed index. The script saves `webcam_environment_test.jpg`.

# %%
upload_evidence('02_usb_webcam')

# %% [markdown]
# | Webcam item | Result |
# |---|---|
# | Detected video devices | TYPE HERE |
# | Selected camera index | TYPE HERE |
# | Test frame obtained | YES / NO |
# | Frame in focus | YES / NO |
# | Reflection level | LOW / MEDIUM / HIGH |
#
# **Q3.** What does `/dev/video0` or another `/dev/video*` entry represent? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q4.** Why must a raw webcam frame be tested before loading the AI model? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q5.** Explain how camera index, focus, and reflections can affect the experiment. **[2 marks]**
# **Answer:** TYPE HERE

# %% [markdown]
# ## 3. Clone the group fork on Raspberry Pi 5
#
# Replace the example values with the group's fork information:
#
# ```bash
# cd ~
# rm -rf lab4-megalopa-student
#
# git clone https://github.com/FORK_OWNER/FORK_REPOSITORY_NAME.git lab4-megalopa-student
# cd ~/lab4-megalopa-student
#
# git remote -v
# git rev-parse HEAD
# find student_work/models -maxdepth 2 -type f | sort
# ```
#
# The clone is read-only for this session, so no token is required when the fork is public.

# %%
upload_evidence('03_clone_fork')

# %% [markdown]
# | Git item | Result |
# |---|---|
# | Fork URL | TYPE HERE |
# | Commit ID on Pi | TYPE HERE |
# | Session 1 commit matches | YES / NO |
# | `.pt` model found | YES / NO |
# | ONNX model found | YES / NO |
#
# **Q6.** Why does the Pi clone the group fork instead of the instructor upstream repository? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q7.** Why must the commit ID on the Pi match the final Session 1 commit ID? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q8.** Why is authentication not required for cloning the public fork, but required for pushing to it? **[2 marks]**
# **Answer:** TYPE HERE

# %% [markdown]
# ## 4. Verify the model and software environment
#
# From the cloned fork:
#
# ```bash
# cd ~/lab4-megalopa-student
# find student_work/models -maxdepth 2 -type f | sort
# python3 shared/pi5/check_pi5_environment.py --camera-index 0
# ```

# %%
upload_evidence('04_models_environment')

# %% [markdown]
# | Item | Result |
# |---|---|
# | Selected first model | TYPE HERE |
# | Model format | TYPE HERE |
# | Model size | TYPE HERE |
# | OpenCV version | TYPE HERE |
# | Ultralytics version | TYPE HERE |
# | Environment check | PASSED / FAILED |
#
# **Q9.** Which Session 1 model files are available on the Pi, and which will you test first? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q10.** Why must OpenCV, Ultralytics, and the webcam all be verified before inference? **[2 marks]**
# **Answer:** TYPE HERE

# %% [markdown]
# ## 5. Run static-image inference
#
# Choose an actual validation image filename:
#
# ```bash
# python3 shared/pi5/megalopa_detection_usb.py \
#   --mode image \
#   --source shared/validation/images/VALIDATION_IMAGE.jpg \
#   --confidence 0.25 \
#   --imgsz 640
# ```
#
# When `--model` is omitted, the script lists the models stored in `student_work/models/`.

# %%
upload_evidence('05_static_inference')

# %% [markdown]
# | Static inference item | Result |
# |---|---|
# | Selected model | TYPE HERE |
# | Model format | TYPE HERE |
# | Actual count | TYPE HERE |
# | Predicted count | TYPE HERE |
# | Confidence threshold | TYPE HERE |
# | Inference latency | TYPE HERE |
#
# **Q11.** Why should static-image inference be completed before live webcam inference? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q12.** What is the purpose of the confidence threshold? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q13.** Calculate the absolute count error and state whether the model overcounted or undercounted. **[2 marks]**
# **Answer:** TYPE HERE

# %% [markdown]
# ## 6. Run live USB-webcam inference in the local Pi GUI
#
# ```bash
# python3 shared/pi5/megalopa_detection_usb.py \
#   --mode camera \
#   --camera-index 0 \
#   --confidence 0.25 \
#   --imgsz 640
# ```
#
# Controls:
#
# - `S`: save the current annotated frame to `student_work/results/pi5/`
# - `Q`: stop the program and save a performance summary

# %%
upload_evidence('06_live_webcam')

# %% [markdown]
# | Live inference item | Result |
# |---|---|
# | Selected model | TYPE HERE |
# | Actual count | TYPE HERE |
# | Predicted count | TYPE HERE |
# | Average latency | TYPE HERE |
# | Average FPS | TYPE HERE |
# | Saved annotated frame | YES / NO |
#
# **Q14.** What is edge inference, and why is the live result displayed directly on the Pi kit? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q15.** Explain the relationship between inference latency and FPS. **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q16.** State one webcam or lighting condition that affected live detection. **[2 marks]**
# **Answer:** TYPE HERE

# %% [markdown]
# ## 7. Compare two model formats
#
# Run the same fixed image or the same controlled webcam scene using `.pt` and ONNX. Keep confidence and input size unchanged.

# %%
upload_evidence('07_model_comparison')

# %% [markdown]
# | Format | Predicted count | Latency | FPS | File size |
# |---|---:|---:|---:|---:|
# | `.pt` | TYPE HERE | TYPE HERE | TYPE HERE | TYPE HERE |
# | ONNX | TYPE HERE | TYPE HERE | TYPE HERE | TYPE HERE |
#
# **Q17.** Which format was faster, and were the predicted counts equivalent? **[2 marks]**
# **Answer:** TYPE HERE
#
# **Q18.** Why is the fastest model format not automatically the most accurate or most suitable? **[2 marks]**
# **Answer:** TYPE HERE

# %% [markdown]
# ## 8. Confidence and temperature observation
#
# Run one additional test with a different confidence value, then record temperature:
#
# ```bash
# vcgencmd measure_temp
# ```

# %%
upload_evidence('08_confidence_temperature')

# %% [markdown]
# | Observation | Result |
# |---|---|
# | Alternative confidence | TYPE HERE |
# | Effect on detections | TYPE HERE |
# | Initial temperature | TYPE HERE |
# | Final temperature | TYPE HERE |
#
# **Q19.** Explain how confidence affects false positives and missed detections, and why CPU temperature is monitored. **[2 marks]**
# **Answer:** TYPE HERE

# %% [markdown]
# ## 9. Final evidence and traceability
#
# Capture one final image showing:
#
# - the Raspberry Pi 5 kit and USB webcam;
# - the live detection window;
# - the selected model name;
# - predicted count, latency, and FPS.

# %%
upload_evidence('09_final_system')

# %% [markdown]
# | Final item | Result |
# |---|---|
# | Group fork URL | TYPE HERE |
# | Session 1 commit ID | TYPE HERE |
# | Model used on Pi | TYPE HERE |
# | Actual count | TYPE HERE |
# | Predicted count | TYPE HERE |
# | Average latency | TYPE HERE |
# | Average FPS | TYPE HERE |
#
# **Q20.** Explain how the fork URL, commit ID, model filename, and captured Pi result make the deployment reproducible. **[2 marks]**
# **Answer:** TYPE HERE
#
# ## Session 2 PDF submission
#
# 1. Confirm all 20 answers are complete.
# 2. Confirm all required evidence images are visible.
# 3. Use **File → Print → Save as PDF**.
# 4. Submit `SecXX_GroupXX_Lab4_Session2.pdf` through Google Classroom.
# 5. Do not display passwords or access tokens.
